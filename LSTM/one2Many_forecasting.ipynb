# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)

# %%
df=pd.read_csv("../DataFrames/NYC_Central_Park_weather_1869-2022.csv")
df['DATE']=pd.to_datetime(df['DATE'])
df["DATE"] = df["DATE"].dt.strftime("%m-%d-%Y")
df['DATE']=pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)

# %%
df['Temp']=(df["TMAX"]+df['TMIN'])/2
temp=df['Temp']
print(temp.isna().sum())
temp = temp.ffill()
print(temp.isna().sum())
print(temp.head())

temp.plot(figsize=(18, 6))
# Out:
# 7
# 0
# DATE
# 1869-01-01    24.0
# 1869-01-02    24.0
# 1869-01-03    31.0
# 1869-01-04    35.5
# 1869-01-05    40.0
# Name: Temp, dtype: float64
# <Axes: xlabel='DATE'>

# %%
def df_to_array(df, window_size):
    df_as_np=df.to_numpy()
    #print(df_as_np)
    X=[]
    y=[]
    for i in range(len(df_as_np)-window_size):
        row=[[a] for a in df_as_np[i:i+window_size]]
        X.append(row)
        label=df_as_np[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE=60
X, y =df_to_array(temp, WINDOW_SIZE)
#X.shape, y.shape
print(temp.shape)
# Out:
# (56245,)

# %%
X_train, y_train=X[:46000], y[:46000]
X_val, y_val=X[46000:51150], y[46000:51150]
X_test, y_test=X[51150:], y[51150:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((46000, 60, 1), (46000,), (5150, 60, 1), (5150,), (5035, 60, 1), (5035,))

# %%
from tensorflow.keras.models import Sequential              #to
from tensorflow.keras.layers import *                       #to 
from tensorflow.keras.callbacks import ModelCheckpoint      #to save the model that does best on validations
from tensorflow.keras.losses import MeanSquaredError        # to 
from tensorflow.keras.metrics import RootMeanSquaredError   # sqrt of the errror
from tensorflow.keras.optimizers import Adam

# %%
model1=Sequential()                                 #Creates a neural network 
model1.add(InputLayer((WINDOW_SIZE, 1)))            #Tells the models teh shape on one training example
model1.add(LSTM(64))                                
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))
model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp=ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 1798.7317 - root_mean_squared_error: 42.4115 - val_loss: 902.7893 - val_root_mean_squared_error: 30.0465
# Epoch 2/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 447.4747 - root_mean_squared_error: 21.1536 - val_loss: 187.6826 - val_root_mean_squared_error: 13.6997
# Epoch 3/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 92.2235 - root_mean_squared_error: 9.6033 - val_loss: 47.8787 - val_root_mean_squared_error: 6.9194
# Epoch 4/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 38.1084 - root_mean_squared_error: 6.1732 - val_loss: 32.0463 - val_root_mean_squared_error: 5.6609
# Epoch 5/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 32.1250 - root_mean_squared_error: 5.6679 - val_loss: 29.1423 - val_root_mean_squared_error: 5.3984
# Epoch 6/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 30.7580 - root_mean_squared_error: 5.5460 - val_loss: 28.3023 - val_root_mean_squared_error: 5.3200
# Epoch 7/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - loss: 30.2273 - root_mean_squared_error: 5.4979 - val_loss: 27.9778 - val_root_mean_squared_error: 5.2894
# Epoch 8/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 29.9563 - root_mean_squared_error: 5.4732 - val_loss: 28.6920 - val_root_mean_squared_error: 5.3565
# Epoch 9/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 29.8103 - root_mean_squared_error: 5.4599 - val_loss: 27.8992 - val_root_mean_squared_error: 5.2820
# Epoch 10/10
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 29.7427 - root_mean_squared_error: 5.4537 - val_loss: 27.6562 - val_root_mean_squared_error: 5.2589

# %%
from tensorflow.keras.models import load_model
model1=load_model('model1.keras')

# %%
train_predicions=model1.predict(X_train).flatten()
train_results=pd.DataFrame(data={'Train Predictions': train_predicions, 'Actuals': y_train})
train_results
# Out:
# 1438/1438 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step
#        Train Predictions  Actuals
# 0              20.272209     27.5
# 1              34.267597     35.5
# 2              33.755070     31.5
# 3              30.436262     23.0
# 4              24.292591     28.0
# ...                  ...      ...
# 45995          34.848610     18.0
# 45996          19.260670     13.0
# 45997          20.811529     20.0
# 45998          26.372105     23.0
# 45999          25.817379     23.0
#
# [46000 rows x 2 columns]

# %%
plt.plot(train_results["Train Predictions"][:30], label='Train Predictions')
plt.plot(train_results["Actuals"][:30], label='Real Data')

# %%
val_predicions=model1.predict(X_val).flatten()
val_results=pd.DataFrame(data={'Validation Predictions': val_predicions, 'Actuals': y_val})
val_results
# Out:
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Validation Predictions  Actuals
# 0                  25.956434     33.5
# 1                  35.828083     38.0
# 2                  34.855354     19.5
# 3                  19.424347     20.0
# 4                  26.830334     27.0
# ...                      ...      ...
# 5145               37.109364     33.5
# 5146               37.609386     41.5
# 5147               44.364437     46.5
# 5148               45.737736     43.5
# 5149               43.200710     45.5
#
# [5150 rows x 2 columns]

# %%
plt.plot(val_results["Validation Predictions"][:30], label='Validation Predictions')
plt.plot(val_results["Actuals"][:30], label="Real Data")

# %%
test_predictions=model1.predict(X_test).flatten()
test_results=pd.DataFrame(data={'Test Predictions': test_predictions, 'Actuals': y_test})
test_results
# Out:
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Test Predictions  Actuals
# 0            45.981430     52.5
# 1            50.395176     47.5
# 2            45.689228     39.5
# 3            41.196968     40.0
# 4            43.295094     44.5
# ...                ...      ...
# 5030         16.941055     21.0
# 5031         31.395134     23.5
# 5032         25.467813     32.0
# 5033         36.364353     40.0
# 5034         37.874996     45.5
#
# [5035 rows x 2 columns]

# %%
plt.figure(figsize=(24, 8))
plt.plot(range(-1, -1+len(test_results["Test Predictions"][:365])),test_results["Test Predictions"][:365], label='Test Predictions')
plt.plot(test_results["Actuals"][:365], label='Real Data')

# %%
next_100_years=pd.date_range(
    start="01-01-2023",
    periods=36500,
    freq='D'
)
print(next_100_years)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2122-11-28', '2122-11-29', '2122-11-30', '2122-12-01',
#                '2122-12-02', '2122-12-03', '2122-12-04', '2122-12-05',
#                '2122-12-06', '2122-12-07'],
#               dtype='datetime64[us]', length=36500, freq='D')

# %%
future_predictions=temp.values[-60:].tolist()
for i in range(365):
    currentWindow=np.array([[[a] for a in future_predictions[-WINDOW_SIZE:]]])
    prediction=model1.predict(currentWindow, verbose=0)
    future_predictions.append(prediction[0][0])

# %%
print(len(temp))
print(len(future_predictions))
print(len(future_predictions)-len(temp))

future_predictions = np.array(future_predictions).reshape(-1)
new_Year=pd.DataFrame({'values': future_predictions})
#print(new_Year.head())
plt.plot(new_Year['values'][60:])
print(future_predictions)
# Out:
# 56245
# 425
# -55820
# [58.         63.         62.         59.5        61.5        70.
#  70.5        65.5        52.5        46.5        56.5        63.5
#  64.5        51.         41.         40.5        44.5        41.5
#  39.         35.5        35.         34.         44.         48.5
#  47.         50.5        49.5        54.         47.5        40.
#  49.         39.         39.5        51.5        41.5        42.
#  50.         56.5        48.5        40.5        35.5        36.5
#  33.         32.5        35.         37.5        41.         40.
#  36.         35.         34.5        33.5        41.         33.
#  11.         21.         23.5        32.         40.         45.5
#  41.89112091 37.55362701 35.92211914 35.27246475 34.91899872 34.65742874
#  34.42812347 34.22660446 34.06256104 33.93824005 33.82842636 33.71205521
#  33.59756851 33.49881744 33.41381454 33.33478546 33.26068497 33.19165421
#  33.12434006 33.05472183 32.98210526 32.91273499 32.85080719 32.79441833
#  32.74212646 32.69407272 32.6499176  32.61005783 32.57588577 32.54419708
#  32.51331711 32.48400497 32.45380783 32.42752838 32.40835953 32.39140701
#  32.38064194 32.3869133  32.41374207 32.45131302 32.48301315 32.50355148
#  32.51707458 32.51934052 32.51300812 32.50901794 32.51803589 32.54619598
#  32.58441544 32.6182518  32.64798355 32.67091751 32.69384384 32.76891327
#  32.82617569 32.73466492 32.59153748 32.47919083 32.41046143 32.38286209
#  32.38511276 32.39977646 32.41328812 32.4224205  32.42877579 32.43391037
#  32.43856812 32.44297791 32.44721222 32.45135117 32.45551682 32.45976257
#  32.46405792 32.46835327 32.47264481 32.47694397 32.48126602 32.48561859
#  32.49000549 32.49440765 32.49878693 32.50308609 32.50726318 32.51129913
#  32.51517868 32.51889038 32.52242661 32.52576828 32.52889633 32.53181076
#  32.53450012 32.53695679 32.53916168 32.54108047 32.54268265 32.5439682
#  32.54492569 32.54554749 32.54590225 32.54611969 32.54633331 32.54660034
#  32.54690933 32.54723358 32.54752731 32.54773712 32.54785919 32.54795456
#  32.54814148 32.54851913 32.54913712 32.55002975 32.5512085  32.55277634
#  32.55504227 32.55805588 32.56128311 32.56409073 32.5662117  32.5676651
#  32.56863022 32.56930923 32.56985474 32.5703392  32.57078552 32.57118988
#  32.57155228 32.57186508 32.57213974 32.57237625 32.5725708  32.5727272
#  32.57284546 32.5729332  32.57299042 32.57301712 32.57301712 32.57299423
#  32.57294846 32.57288361 32.57279968 32.57270432 32.57260132 32.57249069
#  32.57237625 32.57226181 32.57214737 32.57203293 32.57191849 32.57179642
#  32.57168579 32.57157898 32.5714798  32.57138824 32.57130432 32.57122803
#  32.57115173 32.57107544 32.57100296 32.57093048 32.57085037 32.57076645
#  32.57068253 32.57059097 32.57049179 32.57038498 32.57027054 32.57014084
#  32.57000732 32.56985855 32.56969452 32.56951904 32.56933975 32.56914902
#  32.56894684 32.56874084 32.56855011 32.56837082 32.56820297 32.56805038
#  32.56790924 32.56778336 32.5676651  32.56754684 32.5674324  32.56732559
#  32.56722641 32.56713486 32.56704712 32.5669632  32.56688309 32.56680679
#  32.5667305  32.56666183 32.5666008  32.56653976 32.56648254 32.56642914
#  32.56638336 32.56633377 32.56628799 32.56624603 32.56620789 32.56617355
#  32.56613922 32.5661087  32.566082   32.5660553  32.56603241 32.56601334
#  32.56599045 32.56596756 32.56594467 32.5659256  32.56590652 32.56588745
#  32.56587219 32.56586075 32.56585312 32.56584549 32.56584167 32.56583786
#  32.56583405 32.56583023 32.56583023 32.56583023 32.56583405 32.56584167
#  32.5658493  32.56585312 32.56586075 32.56586838 32.56587601 32.56588745
#  32.5658989  32.56591034 32.56592178 32.56592941 32.56593704 32.56594849
#  32.56595993 32.56597137 32.56598282 32.56599426 32.56600571 32.56602097
#  32.56603241 32.56604385 32.5660553  32.56606674 32.566082   32.56609344
#  32.56610107 32.5661087  32.56611633 32.56612778 32.56613922 32.56614685
#  32.56615829 32.56616592 32.56617355 32.56618118 32.56619263 32.56620407
#  32.5662117  32.56621552 32.56621933 32.56622314 32.56622696 32.56623459
#  32.56624222 32.56624985 32.56625748 32.56626129 32.56626892 32.56627655
#  32.56627655 32.56628036 32.56628418 32.56628799 32.56628799 32.56628799
#  32.56629181 32.56629944 32.56629944 32.56630325 32.56630325 32.56630325
#  32.56630325 32.56630707 32.56631088 32.5663147  32.5663147  32.5663147
#  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147
#  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147
#  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147
#  32.5663147  32.5663147  32.5663147  32.5663147  32.5663147  32.56631088
#  32.56630707 32.56630707 32.56631088 32.56630707 32.56630325 32.56630325
#  32.56630325 32.56630325 32.56630325 32.56630325 32.56630325 32.56630325
#  32.56630325 32.56630325 32.56630325 32.56630325 32.56630325 32.56630325
#  32.56630325 32.56629944 32.56629944 32.56629944 32.56629944 32.56629944
#  32.56629944 32.56629944 32.56629944 32.56629944 32.56629944 32.56629944
#  32.56629944 32.56629944 32.56629944 32.56629944 32.56629944 32.56629944
#  32.56629944 32.56629944 32.56629944 32.56629944 32.56629944 32.56629944
#  32.56629944 32.56629944 32.56629944 32.56629944 32.56629944]
