# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../DataFrames/NYC_Central_Park_weather_1869-2022.csv")
df['DATE']=pd.to_datetime(df['DATE'])
df["DATE"] = df["DATE"].dt.strftime("%m-%d-%Y")
df['DATE']=pd.to_datetime(df['DATE'])
#df.set_index('DATE', inplace=True)
df['Temp']=(df["TMAX"]+df['TMIN'])/2
temp=df[['Temp', 'DATE']]
print(temp.isna().sum())
temp = temp.ffill()
print(df.info())
# Out:
# Temp    7
# DATE    0
# dtype: int64
# <class 'pandas.DataFrame'>
# RangeIndex: 56245 entries, 0 to 56244
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    56245 non-null  datetime64[us]
#  1   PRCP    56245 non-null  float64
#  2   SNOW    56082 non-null  float64
#  3   SNWD    39687 non-null  float64
#  4   TMIN    56238 non-null  float64
#  5   TMAX    56238 non-null  float64
#  6   Temp    56238 non-null  float64
# dtypes: datetime64[us](1), float64(6)
# memory usage: 3.0 MB
# None

# %%
#This creates cyclical feautures
temp['day_sin']=np.sin(2*np.pi*df['DATE'].dt.day/365)
temp['day_cos']=np.cos(2*np.pi*df['DATE'].dt.day/365)
print(temp.head())
# Out:
#    Temp       DATE   day_sin   day_cos
# 0  24.0 1869-01-01  0.017213  0.999852
# 1  24.0 1869-01-02  0.034422  0.999407
# 2  31.0 1869-01-03  0.051620  0.998667
# 3  35.5 1869-01-04  0.068802  0.997630
# 4  40.0 1869-01-05  0.085965  0.996298
